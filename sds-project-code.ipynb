# %%
# 1. Import of packages

import pandas as pd

# %%
# 2. Read data

fp = "data/stzh.zwn_meldungen_p.csv"
zh_data = pd.read_csv(fp)

print("Data loaded successfully")
# Out:
# Data loaded successfully

# %%
# 3. Cleaning and preparing the csv-data of Zueriwieneu requests with Pandas

    # Deleting unnecessary columns
zh_data = zh_data.drop(columns=["objectid", "agency_sent_datetime", "service_code", "media_url"])

    # Setting service_request_id as the index of the df (object_id is not stable over time according to the data description on the web page)
zh_data = zh_data.set_index("service_request_id")

    # Define new names for columns if necessary
new_names = {"e": "lon",
             "n": "lat"}
zh_data = zh_data.rename(columns=new_names)

    # Parse the date-time columns
zh_data["requested_datetime"] = pd.to_datetime(zh_data["requested_datetime"], format="%Y-%m-%dT%H:%M:%S")
zh_data["updated_datetime"] = pd.to_datetime(zh_data["updated_datetime"], format="%Y-%m-%dT%H:%M:%S")

# Export the cleaned csv to work with it later
    # Define the output file name
output_file = "data/stzh.zwn_meldungen_p_cleaned.csv"

    # Save DataFrame to a new CSV file
zh_data.to_csv(output_file, index=False)
display(zh_data.head())
zh_data.info()
# Out:
#                     requested_datetime    updated_datetime      lon      lat  \
# service_request_id
# 1                  2013-03-14 15:16:15 2013-04-12 07:59:30  2678968  1247548
# 2                  2013-03-14 15:17:57 2013-04-12 08:00:22  2680746  1249916
# 4                  2013-03-15 09:14:16 2013-04-12 08:08:10  2684605  1251431
# 5                  2013-03-15 09:17:15 2013-04-12 08:09:05  2681754  1250376
# 6                  2013-03-15 10:36:53 2013-04-23 13:50:33  2683094  1247762
#
#                               service_name           status  userid  \
# service_request_id
# 1                   Strasse/Trottoir/Platz  fixed - council   16624
# 2                   Strasse/Trottoir/Platz  fixed - council   16624
# 4                   Strasse/Trottoir/Platz  fixed - council   16624
# 5                   Strasse/Trottoir/Platz  fixed - council   16624
# 6                      Abfall/Sammelstelle  fixed - council   16624
#
#                           title  \
# ...
